// %% [markdown]
// #### Mohammed Mohsin Dyer
// #### #V00930385

// %% [markdown]
// ## Assignment 1
// ### Part 2

// %% [markdown]
// **1**

// %% [markdown]
// a) Initializing two quibits
//
// <img src="Screen Shot 2021-05-20 at 6.52.03 PM.png" width="600" align="left">

// %% [markdown]
// b) Adding Pauli Gates
//
// <img src="Screen Shot 2021-05-20 at 6.55.26 PM.png" width="600" align="left">

// %% [markdown]
// c) Hadamard and Cx-gate
//
// <img src="Screen Shot 2021-05-20 at 6.56.38 PM.png" width="600" align="left">

// %% [markdown]
// d) Introducing Barriers
//
// <img src="Screen Shot 2021-05-20 at 6.58.45 PM.png" width="600" align="left">

// %% [markdown]
// **2**

// %%
# code from IBM's quantum circuit conversion tool

from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.reset(qreg_q[0])
circuit.reset(qreg_q[1])
circuit.barrier(qreg_q[0])
circuit.barrier(qreg_q[1])
circuit.z(qreg_q[0])
circuit.id(qreg_q[1])
circuit.barrier(qreg_q[0])
circuit.barrier(qreg_q[1])
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.barrier(qreg_q[0])
circuit.barrier(qreg_q[1])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])
circuit.draw()
// Out:
//            ░ ┌───┐ ░ ┌───┐ ░      ┌─┐
// q_0: ─|0>──░─┤ Z ├─░─┤ H ├─░───■──┤M├───
//            ░ ├───┤ ░ ├───┤ ░ ┌─┴─┐└╥┘┌─┐
// q_1: ─|0>──░─┤ I ├─░─┤ H ├─░─┤ X ├─╫─┤M├
//            ░ └───┘ ░ └───┘ ░ └───┘ ║ └╥┘
// c: 2/══════════════════════════════╩══╩═
//                                    0  1

// %% [markdown]
// **3**

// %%
# code from IBM's quantum circuit conversion tool

OPENQASM 2.0;
include "qelib1.inc";

qreg q[2];
creg c[2];

reset q[0];
reset q[1];
barrier q[0];
barrier q[1];
z q[0];
id q[1];
barrier q[0];
barrier q[1];
h q[0];
h q[1];
barrier q[0];
barrier q[1];
cx q[0],q[1];
measure q[0] -> c[0];
measure q[1] -> c[1];
// Out:
// /snippet_.qs(1,10): error QS3035: Unexpected code fragment.
// /snippet_.qs(1,1): error QS3036: An expression used as a statement must be a call expression.
// /snippet_.qs(2,9): error QS3035: Unexpected code fragment.
// /snippet_.qs(2,1): error QS3036: An expression used as a statement must be a call expression.
// /snippet_.qs(4,6): error QS3035: Unexpected code fragment.
// /snippet_.qs(4,1): error QS3036: An expression used as a statement must be a call expression.
// /snippet_.qs(5,6): error QS3035: Unexpected code fragment.
// /snippet_.qs(5,1): error QS3036: An expression used as a statement must be a call expression.
// /snippet_.qs(7,7): error QS3035: Unexpected code fragment.
// /snippet_.qs(7,1): error QS3036: An expression used as a statement must be a call expression.
// /snippet_.qs(8,7): error QS3035: Unexpected code fragment.
// /snippet_.qs(8,1): error QS3036: An expression used as a statement must be a call expression.
// ...

// %% [markdown]
// **4**

// %%
from qiskit.visualization import plot_bloch_vector
%matplotlib inline

// %%
plot_bloch_vector([0,0,1], title="Bloch Sphere qubit 0")
// Out:
// /Users/mohsindyer/opt/anaconda3/envs/lecture1/lib/python3.7/site-packages/qiskit/visualization/bloch.py:402: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
//   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
// /Users/mohsindyer/opt/anaconda3/envs/lecture1/lib/python3.7/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
// The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
//   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

// %%
plot_bloch_vector([0,0,-1], title="Bloch Sphere qubit 0")
// Out:
// /Users/mohsindyer/opt/anaconda3/envs/lecture1/lib/python3.7/site-packages/qiskit/visualization/bloch.py:402: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
//   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
// /Users/mohsindyer/opt/anaconda3/envs/lecture1/lib/python3.7/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
// The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
//   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

// %%
plot_bloch_vector([1,0,0], title="Bloch Sphere qubit 0")
// Out:
// /Users/mohsindyer/opt/anaconda3/envs/lecture1/lib/python3.7/site-packages/qiskit/visualization/bloch.py:402: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
//   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
// /Users/mohsindyer/opt/anaconda3/envs/lecture1/lib/python3.7/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
// The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
//   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

// %%
plot_bloch_vector([-1,0,0], title="Bloch Sphere qubit 0")
// Out:
// /Users/mohsindyer/opt/anaconda3/envs/lecture1/lib/python3.7/site-packages/qiskit/visualization/bloch.py:402: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
//   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
// /Users/mohsindyer/opt/anaconda3/envs/lecture1/lib/python3.7/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
// The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
//   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

// %%
plot_bloch_vector([0,1,0], title="Bloch Sphere qubit 0")
// Out:
// /Users/mohsindyer/opt/anaconda3/envs/lecture1/lib/python3.7/site-packages/qiskit/visualization/bloch.py:402: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
//   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
// /Users/mohsindyer/opt/anaconda3/envs/lecture1/lib/python3.7/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
// The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
//   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

// %%
plot_bloch_vector([0,-1,0], title="Bloch Sphere qubit 0")
// Out:
// /Users/mohsindyer/opt/anaconda3/envs/lecture1/lib/python3.7/site-packages/qiskit/visualization/bloch.py:402: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
//   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
// /Users/mohsindyer/opt/anaconda3/envs/lecture1/lib/python3.7/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
// The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
//   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
